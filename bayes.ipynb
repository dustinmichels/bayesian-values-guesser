# %%
import pandas as pd
import numpy as np

from data_prep import (
    all_vars, load_files, about_q, parse_categories,
    locate_col_lables, get_col_labels)

# %%
def head_and_tail(df, n=4):
    """Show first and last n items in DF"""
    return df.iloc[np.r_[0:n, -n:0]]

# %% [markdown]
# ## Load / View data fies

# %%
responses, codebook = load_files()

# %%
# responses has (90350) individual responses to 339 questions,
# identified by id

head_and_tail(responses, n=3)
# Out:
#        V1   V2  V2A      V3  V4  V5  V6  V7  V8  V9  ...    V256B  V256C  \
# 0       6   12   12     1.0   1   1   1  -2   1   1  ...       -4     -4
# 1       6   12   12     2.0   1   2   3   4   2   2  ...       -4     -4
# 2       6   12   12     3.0   1   3   2   4   2   1  ...       -4     -4
# 90347   6  716  716  1498.0   1   2   1   3   1   1  ...   716014     -4
# 90348   6  716  716  1499.0   1   2   2   3   1   1  ...   716011     -4
# 90349   6  716  716  1500.0   1   2   2   2   2   1  ...   716011     -4
#
#        V256_MAP   V257    V258   V258A  V260      V261  V262  V265
# 0            -4  12001  1.0000  1.0000     5        -4  2013    -4
# 1            -4  12001  1.0000  1.0000     5        -4  2013    -4
# 2            -4  12001  1.0000  1.0000     5        -4  2013    -4
# 90347        -4    405  2.2801  2.2801     3  20120115  2012    -4
# 90348        -4    405  2.2801  2.2801     3  20120114  2012    -4
# 90349        -4    405  2.2801  2.2801     3  20120114  2012    -4
#
# [6 rows x 339 columns]

# %%
# codebook attaches a label and question to each var,
# and the categories that answers correspond to

head_and_tail(codebook, n=2)
# Out:
#                         label                 question  \
# V1                       Wave              Wave number
# V2               Country Code             Country code
# V264              Nation Year              Nation Year
# V265  Respondent's occupation  Respondent's occupation
#
#                                              categories
# V1    1##1981-1984\n2##1989-1993\n3##1994-1999\n4##1...
# V2                                                  NaN
# V264  81998##Albania (1998)\n82002##Albania (2002)\n...
# V265  1##Employer/ manager of establishment with 10 ...

# %% [markdown]
# #### Some helper methods

# %%
# print out info
about_q(codebook, 'V225')
# Out:
# Label: How often use of a personal computer
#
# Question: How often, if ever, do you use a personal computer?
#
# Categories:
#  1. Never
#  2. Occasionally
#  3. Frequently
#  4. Don´t know what a computer is
# -5. DE,EC:Inapplicable; BH: Missing; RU: Inappropriate response{Inappropriate}
# -4. Not asked in survey
# -3. Not applicable
# -2. No answer
# -1. Don´t know

# %%
# render categories as DF
parse_categories(codebook, 'V25')
# Out:
#     0                                                  1
# 0   0                                       Not a member
# 1   1                                    Inactive member
# 2   2                                      Active member
# 3  -5  SE: Inapplicable;RU: Inappropriate response{In...
# 4  -4                                Not asked in survey
# 5  -3                                     Not applicable
# 6  -2                                          No answer
# 7  -1                                         Don´t know

# %% [markdown]
# ## Experiment with hand-selected subset of vars

# %%
all_vars
# Out:
# {'V10': 'feeling of happiness',
#  'V100': 'Hard work brings success',
#  'V148': 'Believe in God',
#  'V178': 'carried knife for security',
#  'V179': 'victim of crime',
#  'V187': 'war is necessary',
#  'V209': 'Justifiable parents beat children',
#  'V211': 'proud of nationality',
#  'V225': 'how often use personal computer',
#  'V238': 'social class subjective',
#  'V248': 'highest educational level',
#  'V2A': 'country code',
#  'V4': 'import in life: family',
#  'V80': 'most serious world problem'}

# %%
# Drop negative responses
df = responses.loc[:,all_vars]
df = df.mask(df < 0).dropna()

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.dummy import DummyClassifier

def bayes(df, test_var, NB=MultinomialNB, return_clf=False):
    """Given df and test_var, runs Bayesian and baseline classifier.
    Returns results as (clf_score, base_score) tuple."""
    
    # y is test var, X is all other vars
    y = df[test_var]
    y=y.astype('float')
    X = df.drop(test_var, axis=1)
    
    # split into test/training
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.33, random_state=42)
    
    # create, fit, and score bayesian classifier
    clf = NB()
    clf.fit(X_train, y_train)
    clf_score = clf.score(X_test, y_test)
    
    # create, fit, and score baseline classifier
    base = DummyClassifier(strategy='most_frequent', random_state=0)
    base.fit(X_train, y_train)
    base_score = base.score(X_test, y_test)
    
    # return either classifier or scores
    if return_clf:
        return clf
    return clf_score, base_score

# %%
# iteratve over all keys, making list of dicts with score data
res = []
for k, v in all_vars.items():
    score, base_score = bayes(df, test_var=k)
    res.append(
        dict(var=k, des=v, score=score, baseline=base_score))

# %%
res[0]
# Out:
# {'baseline': 0.06242055565643726,
#  'des': 'country code',
#  'score': 0.1208007989831124,
#  'var': 'V2A'}

# %%
# convert list of dicts to DF
res_df = pd.DataFrame(res, columns=['var','des','baseline','score'])

# compute "improve" column (score - baseline)
res_df['improve'] = res_df['score'] - res_df['baseline']

# sort DF by improvement
res_df.sort_values(by=['improve'], ascending=False)
# Out:
#      var                                des  baseline     score   improve
# 11  V225    how often use personal computer  0.388506  0.499818  0.111313
# 0    V2A                       country code  0.062421  0.120801  0.058380
# 13  V248          highest educational level  0.199383  0.215725  0.016343
# 7   V178         carried knife for security  0.928591  0.928591  0.000000
# 9   V209  Justifiable parents beat children  0.515072  0.514981 -0.000091
# 5   V148                     Believe in God  0.869484  0.869167 -0.000318
# 1     V4             import in life: family  0.920056  0.919103 -0.000953
# 6   V179                    victim of crime  0.912657  0.907663 -0.004994
# 12  V238            social class subjective  0.357136  0.351507 -0.005629
# 4   V100           Hard work brings success  0.267432  0.261485 -0.005947
# 8   V187                   war is necessary  0.656846  0.635600 -0.021246
# 2    V10               feeling of happiness  0.507036  0.468631 -0.038406
# 3    V80         most serious world problem  0.561649  0.496595 -0.065054
# 10  V211               proud of nationality  0.598239  0.531505 -0.066733

# %% [markdown]
# ## Data Prep

# %% [markdown]
# ### Some cleaning

# %%
def remove_negatives(responses, cutoff_percent=0.1):
    """Remove all rows with any negative responses.
    Pre-removes columns with more negatives than cutoff_percent"""
    
    # set value based off cutoff_percent and # of responses
    cutoff = cutoff_percent * len(responses)
    
    # count negative responses in each column (s is a Series)
    s = (responses < 0).sum()

    # keep_vars: vars where % negative under cutoff
    keep_vars = s[s <= cutoff]
    keep_vars = list(keep_vars.index)

    # filter df down to keep_vars
    df = responses[keep_vars]

    # Drop negative responses
    df = df.mask(df < 0).dropna()
    
    return df

# %%
df = remove_negatives(responses, cutoff_percent=0.1)
df.shape
# Out:
# (16644, 223)

# %%
def test_all_vars(df, all_vars, NB=MultinomialNB, verbose=False):
    
    # iteratve over all keys, making list of dicts with score data
    res = []
    for k, v in all_vars.items():
        print(k) if verbose else None
        
        score, base_score = bayes(df, test_var=k, NB=NB)
        res.append(dict(var=k, des=v, score=score, baseline=base_score))
        
    # convert list of dicts to DF
    res_df = pd.DataFrame(res, columns=['var','des','baseline','score'])

    # compute "improve" column (score - baseline)
    res_df['improve'] = res_df['score'] - res_df['baseline']

    # sort DF by improvement
    res_df.sort_values(by=['improve'], ascending=False)
    
    return res_df

# %%
drop_vars = {'V1', 'V258', 'V258A', 'V125_16'}

use_df = df.drop(drop_vars, axis=1)
all_vars = codebook.reindex(use_df.columns)['label'].to_dict()

# %%
test_all_vars(use_df, all_vars, verbose=False)
# Out:
# /Users/dustymichels/miniconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:461: RuntimeWarning: divide by zero encountered in log
#   self.class_log_prior_ = (np.log(self.class_count_) -
#       var                                                des  baseline  \
# 0      V2                                       Country Code  0.084653
# 1     V2A                   Country/regions [with split ups]  0.084653
# 2      V3                                   Interview number  0.002731
# 3      V4                          Important in life: Family  0.939559
# 4      V5                         Important in life: Friends  0.452394
# 5      V6                    Important in life: Leisure time  0.408156
# 6      V7                        Important in life: Politics  0.330967
# 7      V8                            Important in life: Work  0.734571
# 8      V9                        Important in life: Religion  0.606772
# 9     V10                               Feeling of happiness  0.435827
# 10    V11                       State of health (subjective)  0.417987
# 11    V12            Important child qualities: independence  0.509376
# 12    V13               Important child qualities: Hard work  0.624977
# 13    V14  Important child qualities: Feeling of responsi...  0.665574
# 14    V15             Important child qualities: Imagination  0.788458
# 15    V16  Important child qualities: Tolerance and respe...  0.677954
# 16    V17  Important child qualities: Thrift saving money...  0.614418
# 17    V18  Important child qualities: Determination, pers...  0.618605
# 18    V19         Important child qualities: Religious faith  0.523758
# 19    V20           Important child qualities: Unselfishness  0.674859
# 20    V21               Important child qualities: Obedience  0.559621
# 21    V22         Important child qualities: Self-expression  0.746951
# 22    V23                        Satisfaction with your life  0.204442
# 23    V24                         Most people can be trusted  0.825414
# 24    V25  Active/Inactive membership: Church or religiou...  0.496268
# 25    V26  Active/Inactive membership: Sport or recreatio...  0.722374
# 26    V27  Active/Inactive membership: Art, music or educ...  0.778627
# 27    V28            Active/Inactive membership: Labor Union  0.802476
# 28    V29        Active/Inactive membership: Political party  0.764610
# 29    V30  Active/Inactive membership: Environmental orga...  0.839978
# ..    ...                                                ...       ...
# 189  V216           I see myself as an autonomous individual  0.386856
# 190  V217                Information source: Daily newspaper  0.264336
# 191  V218              Information source: Printed magazines  0.349536
# 192  V219                        Information source: TV news  0.753140
# 193  V220                     Information source: Radio news  0.477881
# 194  V221                   Information source: Mobile phone  0.461132
# 195  V222                          Information source: Email  0.545057
# 196  V223                       Information source: Internet  0.480066
# 197  V224  Information source: Talk with friends or colle...  0.568906
# 198  V225               How often use of a personal computer  0.439104
# 199  V226                     Vote in elections: local level  0.578919
# 200  V227                  Vote in elections: National level  0.606226
# 201  V229                                  Employment status  0.316221
# 202  V235        Are you the chief wage earner in your house  0.599490
# 203  V237                    Family savings during past year  0.436738
# 204  V238                          Social class (subjective)  0.344256
# 205  V239                                   Scale of incomes  0.205534
# 206  V240                                                Sex  0.498817
# 207  V241                                      Year of birth  0.028946
# 208  V242                                                Age  0.031131
# 209  V243                                   Mother immigrant  0.939195
# 210  V244                                   Father immigrant  0.929729
# 211  V247                                   Language at home  0.115602
# 212  V248                 Highest educational level attained  0.228655
# 213  V250                      Do you live with your parents  0.678682
# 214  V251         Respondent interested during the interview  0.594939
# 215  V256           Region where the interview was conducted  0.023666
# 216  V257          Language in which interview was conducted  0.124522
# 217  V260                              Questionnaire version  0.655562
# 218  V262                                        Survey year  0.488804
#
#         score   improve
# 0    0.517204  0.432551
# 1    0.517204  0.432551
# 2    0.001274 -0.001456
# 3    0.022756 -0.916803
# 4    0.426179 -0.026215
# 5    0.359184 -0.048971
# 6    0.321318 -0.009649
# 7    0.115420 -0.619152
# 8    0.106499 -0.500273
# 9    0.441289  0.005461
# 10   0.397415 -0.020572
# 11   0.520117  0.010741
# 12   0.412525 -0.212452
# 13   0.666121  0.000546
# 14   0.264883 -0.523575
# 15   0.650646 -0.027307
# 16   0.404333 -0.210086
# 17   0.596577 -0.022028
# 18   0.531950  0.008192
# 19   0.363372 -0.311487
# 20   0.557073 -0.002549
# 21   0.295649 -0.451302
# 22   0.093756 -0.110686
# 23   0.230111 -0.595303
# 24   0.518660  0.022392
# 25   0.680320 -0.042054
# 26   0.730566 -0.048061
# 27   0.746769 -0.055707
# 28   0.720553 -0.044056
# 29   0.787002 -0.052977
# ..        ...       ...
# 189  0.121063 -0.265793
# 190  0.244675 -0.019661
# 191  0.160022 -0.189514
# 192  0.040779 -0.712361
# 193  0.185873 -0.292008
# 194  0.294193 -0.166940
# 195  0.185509 -0.359549
# 196  0.255416 -0.224650
# 197  0.172037 -0.396869
# 198  0.271436 -0.167668
# 199  0.208083 -0.370836
# 200  0.193883 -0.412343
# 201  0.075551 -0.240670
# 202  0.598580 -0.000910
# 203  0.280721 -0.156017
# 204  0.340979 -0.003277
# 205  0.138540 -0.066994
# 206  0.503732  0.004915
# 207  0.001820 -0.027125
# 208  0.000546 -0.030584
# 209  0.143819 -0.795376
# 210  0.151830 -0.777899
# 211  0.322046  0.206445
# 212  0.223921 -0.004733
# 213  0.660295 -0.018387
# 214  0.354087 -0.240852
# 215  0.342072  0.318405
# 216  0.321500  0.196978
# 217  0.098489 -0.557073
# 218  0.216821 -0.271983
#
# [219 rows x 5 columns]

# %% [markdown]
# ### Question: What's wrong with V258?
#
# - https://stackoverflow.com/questions/43608007/valueerror-unknown-label-type-in-scikit-learn

# %%
# test_var = 'V257'
test_var = 'V258'
# test_var = 'V2A'

# y is test var, X is all other vars
y = df[test_var]
y = y.astype('float64')
X = df.drop(test_var, axis=1)

# split into test/training
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

y_train.head()
# Out:
# 20579    1.000000
# 72380    1.439769
# 57196    0.762832
# 55349    1.002858
# 74273    0.647469
# Name: V258, dtype: float64

# %%
# create, fit, and score bayesian classifier
clf = MultinomialNB()
clf.fit(X_train, y_train)
clf_score = clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-c0e8f029b566> in <module>()
#       1 # create, fit, and score bayesian classifier
#       2 clf = MultinomialNB()
# ----> 3 clf.fit(X_train, y_train)
#       4 clf_score = clf.score(X_test, y_test)
#
# ~/miniconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     581
#     582         labelbin = LabelBinarizer()
# --> 583         Y = labelbin.fit_transform(y)
#     584         self.classes_ = labelbin.classes_
#     585         if Y.shape[1] == 1:
#
# ~/miniconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py in fit_transform(self, y)
#     305             Shape will be [n_samples, 1] for binary problems.
#     306         """
# --> 307         return self.fit(y).transform(y)
#     308
#     309     def transform(self, y):
#
# ~/miniconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py in fit(self, y)
#     282
#     283         self.sparse_input_ = sp.issparse(y)
# --> 284         self.classes_ = unique_labels(y)
#     285         return self
#     286
#
# ~/miniconda3/lib/python3.6/site-packages/sklearn/utils/multiclass.py in unique_labels(*ys)
#      95     _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#      96     if not _unique_labels:
# ---> 97         raise ValueError("Unknown label type: %s" % repr(ys))
#      98
#      99     ys_labels = set(chain.from_iterable(_unique_labels(y) for y in ys))
#
# ValueError: Unknown label type: (array([1.        , 1.43976859, 0.76283156, ..., 0.77011494, 1.0364008 ,
#        1.        ]),)

# %%
# clf_score

# %%
# base = DummyClassifier(strategy='most_frequent', random_state=0)
# base.fit(X_train, y_train)
# base_score = base.score(X_test, y_test)

# %%
# base_score

# %% [markdown]
# ### Pre-processing with sklearn

# %%
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
# remove cols with low variance

sel = VarianceThreshold(threshold=0.1)
df_new = sel.fit_transform(use_df)

var_df = locate_col_lables(df_new, use_df)

var_df.shape
# Out:
# /Users/dustymichels/miniconda3/lib/python3.6/site-packages/sklearn/utils/__init__.py:93: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(mask.dtype, np.int):
# (16644, 214)

# %%
all_vars = codebook.reindex(var_df.columns)['label'].to_dict()

# %%
test_all_vars(var_df, all_vars, verbose=False)
# Out:
#       var                                                des  baseline  \
# 0      V2                                       Country Code  0.084653
# 1     V2A                   Country/regions [with split ups]  0.084653
# 2      V3                                   Interview number  0.002731
# 3      V5                         Important in life: Friends  0.452394
# 4      V6                    Important in life: Leisure time  0.408156
# 5      V7                        Important in life: Politics  0.330967
# 6      V8                            Important in life: Work  0.734571
# 7      V9                        Important in life: Religion  0.606772
# 8     V10                               Feeling of happiness  0.435827
# 9     V11                       State of health (subjective)  0.417987
# 10    V12            Important child qualities: independence  0.509376
# 11    V13               Important child qualities: Hard work  0.624977
# 12    V14  Important child qualities: Feeling of responsi...  0.665574
# 13    V15             Important child qualities: Imagination  0.788458
# 14    V16  Important child qualities: Tolerance and respe...  0.677954
# 15    V17  Important child qualities: Thrift saving money...  0.614418
# 16    V18  Important child qualities: Determination, pers...  0.618605
# 17    V19         Important child qualities: Religious faith  0.523758
# 18    V20           Important child qualities: Unselfishness  0.674859
# 19    V21               Important child qualities: Obedience  0.559621
# 20    V22         Important child qualities: Self-expression  0.746951
# 21    V23                        Satisfaction with your life  0.204442
# 22    V24                         Most people can be trusted  0.825414
# 23    V25  Active/Inactive membership: Church or religiou...  0.496268
# 24    V26  Active/Inactive membership: Sport or recreatio...  0.722374
# 25    V27  Active/Inactive membership: Art, music or educ...  0.778627
# 26    V28            Active/Inactive membership: Labor Union  0.802476
# 27    V29        Active/Inactive membership: Political party  0.764610
# 28    V30  Active/Inactive membership: Environmental orga...  0.839978
# 29    V31  Active/Inactive membership: Professional assoc...  0.832878
# ..    ...                                                ...       ...
# 184  V213         I see myself as part of my local community  0.439286
# 185  V214       I see myself as part of the [country] nation  0.589295
# 186  V216           I see myself as an autonomous individual  0.386856
# 187  V217                Information source: Daily newspaper  0.264336
# 188  V218              Information source: Printed magazines  0.349536
# 189  V219                        Information source: TV news  0.753140
# 190  V220                     Information source: Radio news  0.477881
# 191  V221                   Information source: Mobile phone  0.461132
# 192  V222                          Information source: Email  0.545057
# 193  V223                       Information source: Internet  0.480066
# 194  V224  Information source: Talk with friends or colle...  0.568906
# 195  V225               How often use of a personal computer  0.439104
# 196  V226                     Vote in elections: local level  0.578919
# 197  V227                  Vote in elections: National level  0.606226
# 198  V229                                  Employment status  0.316221
# 199  V235        Are you the chief wage earner in your house  0.599490
# 200  V237                    Family savings during past year  0.436738
# 201  V238                          Social class (subjective)  0.344256
# 202  V239                                   Scale of incomes  0.205534
# 203  V240                                                Sex  0.498817
# 204  V241                                      Year of birth  0.028946
# 205  V242                                                Age  0.031131
# 206  V247                                   Language at home  0.115602
# 207  V248                 Highest educational level attained  0.228655
# 208  V250                      Do you live with your parents  0.678682
# 209  V251         Respondent interested during the interview  0.594939
# 210  V256           Region where the interview was conducted  0.023666
# 211  V257          Language in which interview was conducted  0.124522
# 212  V260                              Questionnaire version  0.655562
# 213  V262                                        Survey year  0.488804
#
#         score   improve
# 0    0.517204  0.432551
# 1    0.517204  0.432551
# 2    0.001274 -0.001456
# 3    0.426179 -0.026215
# 4    0.359184 -0.048971
# 5    0.321318 -0.009649
# 6    0.115420 -0.619152
# 7    0.106499 -0.500273
# 8    0.441289  0.005461
# 9    0.397415 -0.020572
# 10   0.520117  0.010741
# 11   0.412525 -0.212452
# 12   0.666121  0.000546
# 13   0.264883 -0.523575
# 14   0.650646 -0.027307
# 15   0.404333 -0.210086
# 16   0.596577 -0.022028
# 17   0.531950  0.008192
# 18   0.363372 -0.311487
# 19   0.557073 -0.002549
# 20   0.295649 -0.451302
# 21   0.093756 -0.110686
# 22   0.230111 -0.595303
# 23   0.518660  0.022392
# 24   0.680320 -0.042054
# 25   0.730566 -0.048061
# 26   0.746769 -0.055707
# 27   0.720553 -0.044056
# 28   0.787002 -0.052977
# 29   0.777899 -0.054979
# ..        ...       ...
# 184  0.087930 -0.351356
# 185  0.042600 -0.546696
# 186  0.121063 -0.265793
# 187  0.244675 -0.019661
# 188  0.160022 -0.189514
# 189  0.040779 -0.712361
# 190  0.185873 -0.292008
# 191  0.294193 -0.166940
# 192  0.185509 -0.359549
# 193  0.255416 -0.224650
# 194  0.172037 -0.396869
# 195  0.271436 -0.167668
# 196  0.208083 -0.370836
# 197  0.193883 -0.412343
# 198  0.075551 -0.240670
# 199  0.598580 -0.000910
# 200  0.280721 -0.156017
# 201  0.340979 -0.003277
# 202  0.138540 -0.066994
# 203  0.503732  0.004915
# 204  0.001638 -0.027307
# 205  0.000546 -0.030584
# 206  0.320954  0.205352
# 207  0.223921 -0.004733
# 208  0.660295 -0.018387
# 209  0.354087 -0.240852
# 210  0.341526  0.317859
# 211  0.321318  0.196796
# 212  0.098489 -0.557073
# 213  0.216821 -0.271983
#
# [214 rows x 5 columns]

# %%
# X_new = SelectKBest(chi2, k=10).fit_transform(X, y)
# X_new.shape

# %%
# named_df = locate_col_lables(X_new, df)

# %%
# get_col_labels(named_df, codebook)

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.dummy import DummyClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_new, y, test_size=0.33, random_state=42)

clf = MultinomialNB()
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.517203713817586

# %% [markdown]
# ### Working

# %%
from sklearn import metrics

test_var = 'V2A'

y = use_df[test_var]
X = use_df.drop(test_var, axis=1)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

clf = GaussianNB()
clf.fit(X_train, y_train)
clf.score(X_test, y_test)

# expected = y_test
# predicted = clf.predict(X_test)

# print(metrics.classification_report(expected, predicted))
# print(metrics.confusion_matrix(expected, predicted))
# Out:
# 1.0

# %%
X.shape
# Out:
# (16644, 218)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

X_new = SelectKBest(chi2, k=10).fit_transform(X, y)
X_new.shape
# Out:
# /Users/dustymichels/miniconda3/lib/python3.6/site-packages/sklearn/utils/__init__.py:93: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(mask.dtype, np.int):
# (16644, 10)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_new, y, test_size=0.33, random_state=42)

clf = MultinomialNB()
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.3007464045148371
