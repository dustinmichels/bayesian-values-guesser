# %% [markdown]
# # Bayesian Values Guesser

# %% [markdown]
# ## Retrieving Data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Save paths to data files
# (You have to download these yourself, from http://www.worldvaluessurvey.org/WVSDocumentationWV6.jsp)

# %%
CODEBOOK_FILE = 'data/F00003861-WV6_Codebook_v_2014_11_07.xls'
RESPONSES_FILE = 'data/WV6_Data_ascii_delimited_v_2016_01_01.dat'

# %% [markdown]
# ### Load Codebook

# %%
# Read the codebook excel file
codebook = pd.read_excel(io=CODEBOOK_FILE, sheet='master', header=3)

# Make headers lowercase
codebook.columns = codebook.columns.str.lower()

# Set var name as index
codebook.set_index('var', inplace=True)

# Drop some unwanted columns
codebook.drop(['filter', 'length'], axis=1, inplace=True)

# Drop some unwanted rows
codebook = codebook.iloc[:339]

# %%
codebook.head()
# Out:
#                                 label  \
# var
# V1                               Wave
# V2                       Country Code
# V2A  Country/regions [with split ups]
# V3                   Interview number
# V4          Important in life: Family
#
#                                               question  \
# var
# V1                                         Wave number
# V2                                        Country code
# V2A  Country/regions [with split ups]\r\n\r\nThis i...
# V3                                    Interview number
# V4   For each of the following, indicate how import...
#
#                                             categories
# var
# V1   1##1981-1984\n2##1989-1993\n3##1994-1999\n4##1...
# V2                                                 NaN
# V2A  8##Albania\n12##Algeria\n16##American Samoa\n2...
# V3   1#99999999#1..999999999\n-5##Missing; Unknown\...
# V4   1##Very important\n2##Rather important\n3##Not...

# %%
# When I need the categories, I can parse them
def parse_cat(var):
    vals = codebook.loc[var, 'categories']
    vals = vals.rstrip('\n').split('\n')
    return pd.DataFrame([x.split('##') for x in vals])

# %%
# E.g.,
parse_cat('V4')
# Out:
#     0                                                  1
# 0   1                                     Very important
# 1   2                                   Rather important
# 2   3                                 Not very important
# 3   4                               Not at all important
# 4  -5  BH: Missing; AR,DE,SE: Inapplicable;RU: Inappr...
# 5  -4                                Not asked in survey
# 6  -3                                     Not applicable
# 7  -2                                          No answer
# 8  -1                                         Don´t know

# %% [markdown]
# ### Responses

# %%
# Read responses from csv
responses = pd.read_csv(RESPONSES_FILE, header=None)

# Discard some unwanted columns
responses = responses.loc[:, :338]

# Set values as index
responses.columns = codebook.index.values

# %%
responses.head(n=10)
# Out:
#    V1  V2  V2A    V3  V4  V5  V6  V7  V8  V9  ...   V256B  V256C  V257   V258  \
# 0   6  12   12   1.0   1   1   1  -2   1   1  ...      -4     -4    -4  12001
# 1   6  12   12   2.0   1   2   3   4   2   2  ...      -4     -4    -4  12001
# 2   6  12   12   3.0   1   3   2   4   2   1  ...      -4     -4    -4  12001
# 3   6  12   12   4.0   1   1   3   4   3   1  ...      -4     -4    -4  12002
# 4   6  12   12   5.0   1   1   1   2   1   1  ...      -4     -4    -4  12001
# 5   6  12   12   6.0   1   2   2   2   4   1  ...      -4     -4    -4  12001
# 6   6  12   12   7.0   1   1   1   1   1   1  ...      -4     -4    -4  12001
# 7   6  12   12   8.0   1   1   1   1   2   2  ...      -4     -4    -4  12001
# 8   6  12   12   9.0   1   1   1   2   2   2  ...      -4     -4    -4  12001
# 9   6  12   12  10.0   1   1   1   2   1   1  ...      -4     -4    -4  12001
#
#    V260  V261  V262  V263  V264  V265
# 0   1.0   1.0     5    -4  2013   126
# 1   1.0   1.0     5    -4  2013   126
# 2   1.0   1.0     5    -4  2013   126
# 3   1.0   1.0     5    -4  2013   126
# 4   1.0   1.0     5    -4  2013   126
# 5   1.0   1.0     5    -4  2013   126
# 6   1.0   1.0     5    -4  2013   126
# 7   1.0   1.0     5    -4  2013   126
# 8   1.0   1.0     5    -4  2013   126
# 9   1.0   1.0     5    -4  2013   126
#
# [10 rows x 339 columns]

# %% [markdown]
# ## What percentage of Algerian females believe in God?

# %%
my_vars = {'country' : 'V2A',
           'sex' : 'V240',
           'god': 'V148'}

# %% [markdown]
# Find values

# %%
# Country Algeria
country = parse_cat(my_vars['country'])
country.loc[country[1] == 'Algeria']
# Out:
#     0        1
# 1  12  Algeria

# %%
# Sex female
sex = parse_cat(my_vars['sex'])
sex.loc[sex[1] == 'Female']
# Out:
#    0       1
# 1  2  Female

# %%
# God
god = parse_cat(my_vars['god'])
god.loc[god[1] == 'Yes']
# Out:
#    0    1
# 0  1  Yes

# %%
responses.query('(V2A == 12) & (V240 == 2) & (V148 == 1)')
# Out:
#       V1  V2  V2A      V3  V4  V5  V6  V7  V8  V9  ...   V256B  V256C  V257  \
# 1      6  12   12     2.0   1   2   3   4   2   2  ...      -4     -4    -4
# 2      6  12   12     3.0   1   3   2   4   2   1  ...      -4     -4    -4
# 3      6  12   12     4.0   1   1   3   4   3   1  ...      -4     -4    -4
# 4      6  12   12     5.0   1   1   1   2   1   1  ...      -4     -4    -4
# 7      6  12   12     8.0   1   1   1   1   2   2  ...      -4     -4    -4
# 9      6  12   12    10.0   1   1   1   2   1   1  ...      -4     -4    -4
# 10     6  12   12    11.0   1   2   3   4   1   1  ...      -4     -4    -4
# 13     6  12   12    14.0   1   1   1   1   1   1  ...      -4     -4    -4
# 15     6  12   12    16.0   1   2   2   3   3   4  ...      -4     -4    -4
# 17     6  12   12    18.0   1   1   1   2   1   1  ...      -4     -4    -4
# 19     6  12   12    20.0   1   3   3   4   3   2  ...      -4     -4    -4
# 20     6  12   12    21.0   1   1   1   4   1   1  ...      -4     -4    -4
# 22     6  12   12    23.0   1   1   2   4   1   1  ...      -4     -4    -4
# 23     6  12   12    24.0   1   4   2   4   1   1  ...      -4     -4    -4
# 24     6  12   12    25.0   1   2   1   3   1   1  ...      -4     -4    -4
# 26     6  12   12    27.0   1   1   1   4   1   1  ...      -4     -4    -4
# 28     6  12   12    29.0   1   1   3  -2   1   1  ...      -4     -4    -4
# 31     6  12   12    32.0   1   4   1   4   1   1  ...      -4     -4    -4
# 33     6  12   12    34.0   1   1   1   1   1   1  ...      -4     -4    -4
# 34     6  12   12    35.0   1   4   4   4   1   1  ...      -4     -4    -4
# 36     6  12   12    37.0   1   4   4   4   1   1  ...      -4     -4    -4
# 40     6  12   12    41.0   1   1   2   3   1   1  ...      -4     -4    -4
# 41     6  12   12    42.0   1   2   3  -1   2   1  ...      -4     -4    -4
# 43     6  12   12    44.0   1   3   1   3   1   1  ...      -4     -4    -4
# 45     6  12   12    46.0   1   1   2   3   2   1  ...      -4     -4    -4
# 48     6  12   12    49.0   1   3   2   3   1   1  ...      -4     -4    -4
# 50     6  12   12    51.0   1   1   1   2   3   2  ...      -4     -4    -4
# 51     6  12   12    52.0   1   2   1  -2   1   1  ...      -4     -4    -4
# 52     6  12   12    53.0   1   2   3   4   1   1  ...      -4     -4    -4
# 53     6  12   12    54.0   1   2   2  -2   2   1  ...      -4     -4    -4
# ...   ..  ..  ...     ...  ..  ..  ..  ..  ..  ..  ...     ...    ...   ...
# 1142   6  12   12  1143.0   1   1   2   3  -1   1  ...      -4     -4    -4
# 1145   6  12   12  1146.0   1   1   1   3   1   1  ...      -4     -4    -4
# 1147   6  12   12  1148.0   1   3   3   3   3   1  ...      -4     -4    -4
# 1149   6  12   12  1150.0   1   1   3  -2   1   1  ...      -4     -4    -4
# 1153   6  12   12  1154.0   1   2   1   1   1   1  ...      -4     -4    -4
# 1154   6  12   12  1155.0   1   1   1   1   1   1  ...      -4     -4    -4
# 1155   6  12   12  1156.0   1   1   2   2   1   1  ...      -4     -4    -4
# 1157   6  12   12  1158.0   1   1   1   4   1   1  ...      -4     -4    -4
# 1159   6  12   12  1160.0   2   2   2   2   2   2  ...      -4     -4    -4
# 1161   6  12   12  1162.0   1   1   1   1   1   1  ...      -4     -4    -4
# 1163   6  12   12  1164.0   1   1   1   1   1   1  ...      -4     -4    -4
# 1166   6  12   12  1167.0   1   1   1   1   1   1  ...      -4     -4    -4
# 1167   6  12   12  1168.0   1   1   1   1   1   1  ...      -4     -4    -4
# 1169   6  12   12  1170.0  -1  -1  -1  -1  -1  -1  ...      -4     -4    -4
# 1170   6  12   12  1171.0   1   1   1  -2  -2  -2  ...      -4     -4    -4
# 1171   6  12   12  1172.0   1   1   2   4   1   1  ...      -4     -4    -4
# 1172   6  12   12  1173.0   1   1   1   1   1   1  ...      -4     -4    -4
# 1173   6  12   12  1174.0   1   1   3   3  -1   1  ...      -4     -4    -4
# 1176   6  12   12  1177.0   1   1   1   4   1   1  ...      -4     -4    -4
# 1178   6  12   12  1179.0   1   2   3   3   3   1  ...      -4     -4    -4
# 1182   6  12   12  1183.0   1   3   2   4   1   1  ...      -4     -4    -4
# 1183   6  12   12  1184.0   1   1   1   2   1   1  ...      -4     -4    -4
# 1186   6  12   12  1187.0   1   1   3   2   1   1  ...      -4     -4    -4
# 1187   6  12   12  1188.0   2   1   2   3   2   1  ...      -4     -4    -4
# 1188   6  12   12  1189.0   2   1   1   4   2   1  ...      -4     -4    -4
# 1190   6  12   12  1191.0   1   1   2   2   1   1  ...      -4     -4    -4
# 1191   6  12   12  1192.0   1   1   1   1   1   1  ...      -4     -4    -4
# 1192   6  12   12  1193.0   1   2   3   2   1   1  ...      -4     -4    -4
# 1193   6  12   12  1194.0   1   3   3  -2   1   1  ...      -4     -4    -4
# 1196   6  12   12  1197.0   1   2   4  -2   1   1  ...      -4     -4    -4
#
#        V258  V260  V261  V262  V263  V264  V265
# 1     12001   1.0   1.0     5    -4  2013   126
# 2     12001   1.0   1.0     5    -4  2013   126
# 3     12002   1.0   1.0     5    -4  2013   126
# 4     12001   1.0   1.0     5    -4  2013   126
# 7     12001   1.0   1.0     5    -4  2013   126
# 9     12001   1.0   1.0     5    -4  2013   126
# 10       19   1.0   1.0     5    -4  2013   126
# 13    12001   1.0   1.0     5    -4  2013   126
# 15    12001   1.0   1.0     5    -4  2013   126
# 17    12001   1.0   1.0     5    -4  2013   126
# 19    12001   1.0   1.0     5    -4  2013   126
# 20    12001   1.0   1.0     5    -4  2013   126
# 22    12001   1.0   1.0     5    -4  2013   126
# 23    12001   1.0   1.0     5    -4  2013   126
# 24    12001   1.0   1.0     5    -4  2013   126
# 26    12001   1.0   1.0     5    -4  2013   126
# 28    12001   1.0   1.0     5    -4  2013   126
# 31    12001   1.0   1.0     5    -4  2013   126
# 33    12001   1.0   1.0     5    -4  2013   126
# 34    12001   1.0   1.0     5    -4  2013   126
# 36    12001   1.0   1.0     5    -4  2013   126
# 40       19   1.0   1.0     5    -4  2013   126
# 41       19   1.0   1.0     5    -4  2013   126
# 43       19   1.0   1.0     5    -4  2013   126
# 45       19   1.0   1.0     5    -4  2013   126
# 48    12001   1.0   1.0     5    -4  2013   126
# 50    12001   1.0   1.0     5    -4  2013   126
# 51       19   1.0   1.0     5    -4  2013   126
# 52    12001   1.0   1.0     5    -4  2013   126
# 53    12001   1.0   1.0     5    -4  2013   126
# ...     ...   ...   ...   ...   ...   ...   ...
# 1142  12001   1.0   1.0     5    -4  2013   126
# 1145  12001   1.0   1.0     5    -4  2013   126
# 1147  12001   1.0   1.0     5    -4  2013   126
# 1149  12001   1.0   1.0     5    -4  2013   126
# 1153  12001   1.0   1.0     5    -4  2013   126
# 1154  12001   1.0   1.0     5    -4  2013   126
# 1155  12001   1.0   1.0     5    -4  2013   126
# 1157  12001   1.0   1.0     5    -4  2013   126
# 1159  12001   1.0   1.0     5    -4  2013   126
# 1161  12001   1.0   1.0     5    -4  2013   126
# 1163  12001   1.0   1.0     5    -4  2013   126
# 1166  12001   1.0   1.0     5    -4  2013   126
# 1167  12001   1.0   1.0     5    -4  2013   126
# 1169  12001   1.0   1.0     5    -4  2013   126
# 1170  12001   1.0   1.0     5    -4  2013   126
# 1171    144   1.0   1.0     5    -4  2013   126
# 1172  12001   1.0   1.0     5    -4  2013   126
# 1173  12001   1.0   1.0     5    -4  2013   126
# 1176  12001   1.0   1.0     5    -4  2013   126
# 1178  12001   1.0   1.0     5    -4  2013   126
# 1182  12001   1.0   1.0     5    -4  2013   126
# 1183  12001   1.0   1.0     5    -4  2013   126
# 1186  12001   1.0   1.0     5    -4  2013   126
# 1187  12001   1.0   1.0     5    -4  2013   126
# 1188  12001   1.0   1.0     5    -4  2013   126
# 1190  12001   1.0   1.0     5    -4  2013   126
# 1191  12001   1.0   1.0     5    -4  2013   126
# 1192  12001   1.0   1.0     5    -4  2013   126
# 1193  12001   1.0   1.0     5    -4  2013   126
# 1196  12001   1.0   1.0     5    -4  2013   126
#
# [592 rows x 339 columns]

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
iris.data

# %%
iris.target

# %%
responses.head()

# %%
responses.sample(frac=.80)
# Out:
#        V1   V2  V2A        V3  V4  V5  V6  V7  V8  V9  ...    V256B    V256C  \
# 66503   6  702  702    3320.0   1   1   3   2   1   1  ...       -4       -4
# 31718   6  368  368     160.0   1   1   3   4   1   1  ...        4        4
# 1180    6   12   12    1181.0   1   1   2   3   2   1  ...       -4       -4
# 81545   6  792  792    1533.0   1   1   1   3   1   1  ...       -4       -4
# 17285   6  818  818     275.0   1   3   3   2   1   1  ...       -4  8180098
# 2625    6   51   51     396.0   1   1   1   4   1   1  ...       -4       -4
# 48764   6  528  528  812683.0   1   3   1   3   2   4  ...   528002       -4
# 43792   6  434  434    2176.0   1   1   1   2   1   1  ...       -4       -4
# 26428   6  356  356     529.0   1   2   3   4   1   1  ...       -4       -4
# 5139    6   31   31     333.0   1   1   3   4   3   3  ...    31012       -4
# 39988   6  417  417     784.0   1   2   3   2   3   1  ...       -4       -4
# 18960   6  233  233     429.0   1   2   2   3   2   4  ...       -4       -4
# 52625   6  566  566    1333.0   1   1   1   1   1   1  ...   566016       -4
# 63704   6  646  646      28.0   1   1   2   2   1   1  ...   646024       -4
# 19049   6  233  233     728.0   1   2   1   3   2   4  ...       -4       -4
# 52650   6  566  566    1391.0   1   1   1   2   1   1  ...   566016       -4
# 53708   6  586  586     764.0   1   1   2   2   2   1  ...   586001       -4
# 87691   6  860  860    1342.0   1   1   1   4   1   1  ...       -4       -4
# 5425    6   31   31     619.0   1   1   1   4   3   4  ...    31026       -4
# 12382   6  196  196     841.0   1   1   1   3   1   2  ...       -4       -4
# 54684   6  275  275     447.0   1   2   1   4   1   1  ...       -4       -4
# 43036   6  434  434    1295.0   1   1   4   1   1   1  ...       -4       -4
# 64546   6  646  646     870.0   1   1   2   2   1   1  ...   646011       -4
# 19653   6  233  233    1491.0   1   2   2   2   1   3  ...       -4       -4
# 57712   6  616  616      65.0   2   1   1   3   1   1  ...       -4       -4
# 5227    6   31   31     421.0   1   2   3   3   1   2  ...    31016       -4
# 56703   6  608  608     256.0   1   2   3   2   1   2  ...   608001  6080021
# 15927   6  218  218     321.0   1   3   1   4   1   3  ...       -4       -4
# 15076   6  156  156    1535.0   1   2   2   3   1   4  ...       -4       -4
# 34811   6  392  392    2057.0   1   2   2   2   2   4  ...       -4       -4
# ...    ..  ...  ...       ...  ..  ..  ..  ..  ..  ..  ...      ...      ...
# 60077   6  642  642     404.0   1   2   1   2   1   1  ...       -4       -4
# 89731   6  716  716     882.0   1   3   2   4   1   1  ...   716008       -4
# 43399   6  434  434    1715.0   2   2   2   4   3   1  ...       -4       -4
# 68612   6  410  410     368.0   2   3   3   3   1   3  ...       -4       -4
# 25645   6  344  344     746.0   2   1   2   3   1   2  ...       -4       -4
# 67137   6  702  702    4462.0   1   2   2   2   2   1  ...       -4       -4
# 69043   6  410  410     799.0   1   2   2   2   2   2  ...       -4       -4
# 1559    6   32   32     375.0   1   1   1   3   1   3  ...       -4       -4
# 11324   6  170  170    1295.0   2   3   2   4   1   1  ...       -4       -4
# 62205   6  643  643    1029.0   1   2   2   4   1   4  ...       -4       -4
# 78917   6  788  788     110.0   1   3   3   3   1   1  ...   788002  7880003
# 20267   6  268  268     168.0   1   2   3   3   2   1  ...   268109       -4
# 23515   6  288  288     168.0   1   2   3   3   1   1  ...   288020       -4
# 83779   6  840  840     717.0   1   1   2   4   1   2  ...   840073       -4
# 81462   6  792  792    1450.0   2   1   2   2   2   2  ...       -4       -4
# 11305   6  170  170    1276.0   2   2   2   4   1   1  ...       -4       -4
# 49886   6  528  528  872854.0   1   1   1   2   1   4  ...   528004       -4
# 23178   6  276  901    1902.0   1   1   1   1   2   3  ...       -4       -4
# 84323   6  840  840    1275.0   1   2   2   2   3   1  ...   840085       -4
# 72827   6  710  710    3383.0   1   1   1   1   1   1  ...       -4       -4
# 35489   6  400  400     288.0   1   2   2   1   1   1  ...       -4       -4
# 69482   6  710  710      38.0   1   1   1   2   1   1  ...       -4       -4
# 54193   6  586  586    1315.0   1   2   3   2   1   1  ...   586003       -4
# 34128   6  392  392    1372.0   1   2   2   3   1   4  ...       -4       -4
# 80856   6  792  792     844.0   1   1   2   2   1   1  ...       -4       -4
# 383     6   12   12     384.0   1   1   1   2   1   1  ...       -4       -4
# 75755   6  158  158     385.0   1   2   1   3   1   2  ...       -4       -4
# 3150    6   51   51     921.0   1   2   2   3   1   1  ...       -4       -4
# 27913   6  356  356    2014.0   1   2   2   2   1   1  ...       -4       -4
# 81646   6  804  804       3.0   1   2   4   4   4   1  ...   804080       -4
#
#         V257   V258      V260      V261  V262      V263  V264  V265
# 66503     -4    128  1.195181  1.195181     3        -4  2012  7026
# 31718     -4   1088  1.000000  1.000000     5  20131201  2012  3686
# 1180      -4  12001  1.000000  1.000000     5        -4  2013   126
# 81545     -4   1165  1.008543  1.008543     2  20110714  2011  7926
# 17285     -4     19  0.101296  0.101296     4  20130309  2013  8186
# 2625   51007     25  0.710284  0.710284     2  20111004  2011   516
# 48764     -4    120  1.000000  1.000000     4  20121203  2012  5286
# 43792     -4     19  0.401586  0.401586     4  20140128  2014  4346
# 26428     -4    179  1.000000  1.000000     4        -4  2012  3566
# 5139      -4     40  0.388018  0.388018     3  20111218  2011   316
# 39988     -4    236  1.000000  1.000000     3        -4  2011  4176
# 18960     -4    132  1.099138  1.099138     3        -4  2011  2336
# 52625     -4    173  2.120400  2.120400     3  20120131  2011  5666
# 63704     -4    232  1.000000  1.000000     4  20121130  2012  6466
# 19049     -4    132  1.090514  1.090514     3        -4  2011  2336
# 52650     -4    173  0.623900  0.623900     3  20120130  2011  5666
# 53708     -4    478  1.158436  1.158436     2  20121007  2012  5866
# 87691     -4    479  1.000000  1.000000     3        -4  2011  8606
# 5425      -4     40  0.801037  0.801037     3  20111214  2011   316
# 12382     -4    466  0.655898  0.655898     3  20111015  2011  1966
# 54684     -4   1008  1.000000  1.000000     4  20130224  2013  2756
# 43036     -4     19  0.132550  0.132550     4  20140213  2014  4346
# 64546     -4    232  1.000000  1.000000     4  20121209  2012  6466
# 19653     -4    380  0.937664  0.937664     3        -4  2011  2336
# 57712     -4   1128  0.995283  0.995283     3        -4  2012  6166
# 5227      -4     40  0.388018  0.388018     3  20111220  2011   316
# 56703     -4    140  0.571873  0.571873     3  20120418  2012  6086
# 15927     -4    426  1.000000  1.000000     4        -4  2013  2186
# 15076     -4    289  1.885595  1.885595     4  20121201  2012  1566
# 34811     -4    208  1.000000  1.000000     1        -4  2010  3926
# ...      ...    ...       ...       ...   ...       ...   ...   ...
# 60077     -4    377  0.783772  0.783772     3  20121012  2012  6426
# 89731     -4    405  0.432900  0.432900     3  20120111  2012  7166
# 43399     -4     19  0.892409  0.892409     4  20140127  2014  4346
# 68612     -4     -4  0.547170  0.547170     1        -4  2010  4106
# 25645     -4     73  1.000000  0.000000     4        -4  2013  3446
# 67137     -4    128  0.911266  0.911266     3        -4  2012  7026
# 69043     -4     -4  0.931507  0.931507     1        -4  2010  4106
# 1559      -4    426  1.116469  1.116469     3  20121218  2013   326
# 11324     -4    426  1.000000  1.000000     4        -4  2012  1706
# 62205     -4    380  0.743140  0.743140     3        -4  2011  6436
# 78917     -4     19  1.000000  1.000000     5  20131127  2013  7886
# 20267     -4    157  1.000000  1.000000     4  20141214  2014  2686
# 23515     -4    469  0.493200  0.493200     3  20120119  2012  2886
# 83779     -4    128  0.900000  0.900000     1  20110611  2011  8406
# 81462     -4   1165  1.187119  1.187119     2  20110712  2011  7926
# 11305     -4    426  1.000000  1.000000     4        -4  2012  1706
# 49886     -4    120  1.000000  1.000000     4  20121206  2012  5286
# 23178     -4    158  0.293703  0.109000     4        -4  2013  2766
# 84323     -4    128  1.490000  1.490000     1  20110614  2011  8406
# 72827     -4    128  1.777604  1.777604     4        -4  2013  7106
# 35489     -4     19  1.000000  1.000000     5        -4  2014  4006
# 69482     -4      8  0.547227  0.547227     4        -4  2013  7106
# 54193     -4    478  1.096143  1.096143     2  20121015  2012  5866
# 34128     -4    208  1.000000  1.000000     1        -4  2010  3926
# 80856     -4   1165  0.656034  0.656034     2  20110702  2011  7926
# 383       -4  12001  1.000000  1.000000     5        -4  2013   126
# 75755     -4    289  0.959416  0.959416     3        -4  2012  1586
# 3150   51011     25  0.830332  0.830332     2  20111003  2011   516
# 27913     -4    344  1.000000  1.000000     4        -4  2012  3566
# 81646     -4    475  0.999123  0.999123     3        -4  2011  8046
#
# [72280 rows x 339 columns]
